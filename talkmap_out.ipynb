# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Assuming you are working in a Linux or Windows Subsystem for Linux environment, you may need to install some dependencies. Assuming a clean installation, the following will be needed:
#
# ```bash
# sudo apt install jupyter
# sudo apt install python3-pip
# pip install python-frontmatter getorg --upgrade
# ```
#
# After which you can run this from the `_talks/` directory, via:
#
# ```bash
#  jupyter nbconvert --to notebook --execute talkmap.ipynb --output talkmap_out.ipynb
# ```
#
# The `_talks/` directory contains `.md` files of all your talks. This scrapes the location YAML field from each `.md` file, geolocates it with `geopy/Nominatim`, and uses the `getorg` library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# Start by installing the dependencies
# !pip install python-frontmatter getorg --upgrade
import frontmatter
import glob
import getorg
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# Requirement already satisfied: python-frontmatter in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (1.3.0)
# Requirement already satisfied: getorg in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (0.3.1)
# Requirement already satisfied: pyyaml in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from python-frontmatter) (6.0.3)
# Requirement already satisfied: geopy in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from getorg) (2.9.1)
# Requirement already satisfied: retrying in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from pygithub->getorg) (1.6.2)
# Requirement already satisfied: requests>=2.14.0 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from pygithub->getorg) (2.34.2)
# Requirement already satisfied: pyjwt>=2.4.0 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.13.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from pygithub->getorg) (4.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from pygithub->getorg) (2.7.0)
# Requirement already satisfied: cryptography>=3.4.0 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (49.0.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.1.0)
# Requirement already satisfied: pycparser in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.4.0->pygithub->getorg) (3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from requests>=2.14.0->pygithub->getorg) (3.18)
# Requirement already satisfied: certifi>=2023.5.7 in /home/chaitanya/Miniforge/envs/general/lib/python3.14/site-packages (from requests>=2.14.0->pygithub->getorg) (2026.6.17)
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
# Collect the Markdown files
g = glob.glob("_talks/*.md")

# %%
# Set the default timeout, in seconds
TIMEOUT = 5

# Prepare to geolocate
geocoder = Nominatim(user_agent="chaimain.github.io")
location_dict = {}
location = ""
permalink = ""
title = ""

# %% [markdown]
# In the event that this times out with an error, double check to make sure that the location is can be properly geolocated.

# %%
# Perform geolocation
for file in g:
    # Read the file
    data = frontmatter.load(file)
    data = data.to_dict()

    # Press on if the location is not present
    if 'location' not in data:
        continue

    # Prepare the description
    title = data['title'].strip()
    venue = data['venue'].strip()
    location = data['location'].strip()

    if location.lower() in ["remote", "online", "virtual"]:
        print(f"{title}<br />; held as a/an {location} event")
        continue
    else:
        description = f"{title}<br />{venue}; {location}"

    # Geocode the location and report the status
    try:
        location_dict[description] = geocoder.geocode(location, timeout=TIMEOUT)
        print(description, location_dict[description])
    except ValueError as ex:
        print(f"Error: geocode failed on input {location} with message {ex}")
    except GeocoderTimedOut as ex:
        print(f"Error: geocode timed out on input {location} with message {ex}")
    except Exception as ex:
        print(f"An unhandled exception occurred while processing input {location} with message {ex}")
# Out:
# The Analysis of the first blazars by the Large Size Telescope (LST) of the Cherenkov Telescope Array Observatory (CTAO)<br />The University-Enterprise Foundation of the University of Valencia (ADEIT); Valencia, Spain València, Comarca de València, València / Valencia, Comunitat Valenciana, España
# Can we see light in the ultra-high-energy sky?<br />Saha Institute of Nuclear Physics; Kolkata, India Kolkata, Kolkata Metropolitan Area, Kolkata, West Bengal, India
# Search for UHE photon sources using direction-time clustering algorithms with a BDT particle discriminant<br />Hospederia San Martin Pinario; Santiago de Compostela, Spain Santiago de Compostela, Santiago, A Coruña, Galicia, España
# Looking at the night sky in the very high energy range<br />remote; Bhopal, India Bhopal, Huzur Tahsil, Bhopal, Madhya Pradesh, 462001, India
# Space-Time Clustering analysis using Python<br />Centro Convegni 'Luigi Zordan'; L'Aquila, Italy L'Aquila, Abruzzo, Italia
# Analysis with First Data from Large Size Telescope of Cherenkov Telescope Array<br />Centro de Ciencias de Benasque Pedro Pascual; Benasque, Spain Benasque, Ribagorza, Huesca, Aragón, España
# Ultra-High-Energy Photon Searches with the Pierre Auger Observatory: Constraints, Multi-messenger Synergies, and Future Prospects<br />The University-Enterprise Foundation of the University of Valencia (ADEIT); Valencia, Spain València, Comarca de València, València / Valencia, Comunitat Valenciana, España

# %%
# Save the map
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="talkmap", hashed_usernames=False)
# Out:
# 'Written map to talkmap/'
